# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_rows', 500)

# %%
data_path = "../data/BOLT Data Set.xlsx"
og_df = pd.read_excel(data_path)
og_df.head()
# Out:
#   Card Identifier Transaction Date Transaction Time  Risk Assessment  \
# 0          card 1       2023-05-11       16:22:14.0            362.0
# 1          card 2       2023-06-05       15:16:35.0            602.0
# 2          card 3       2023-06-05       11:57:40.0            482.0
# 3          card 4       2023-07-20       18:26:30.0            947.0
# 4          card 5       2023-03-03       19:03:11.0           1382.0
#
#           Payment Method  Transaction Value Merchant Location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   Card Present Status Chip Usage Cross-border Transaction (Yes/No)  \
# 0                  CP        Yes                                No
# ...

# %%
df = og_df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Card Identifier                    100000 non-null  object
#  1   Transaction Date                   100000 non-null  datetime64[ns]
#  2   Transaction Time                   97963 non-null   datetime64[ns]
#  3   Risk Assessment                    99028 non-null   float64
#  4   Payment Method                     100000 non-null  object
#  5   Transaction Value                  100000 non-null  float64
#  6   Merchant Location                  100000 non-null  object
#  7   Card Present Status                100000 non-null  object
#  8   Chip Usage                         100000 non-null  object
#  9   Cross-border Transaction (Yes/No)  100000 non-null  object
#  10  Acquiring Institution ID           100000 non-null  object
# ...

# %%
from datetime import datetime
def fix_time(time_str):
    og_time = time_str
    if time_str == "na:n:":
        return np.nan
    try:
        time_str = time_str.replace(":", "").replace(".0", "")
        time_str = '{:0>{}}'.format(time_str, 6)
        time_fixed = datetime.strptime(time_str, '%H%M%S')#.strftime('%H:%M:%S')
        return time_fixed
    except Exception as e:
        print(e)
        print(og_time)
        return np.nan

df['Transaction Time'] = df['Transaction Time'].apply(fix_time)

# %%
df.head()
# Out:
#   Card Identifier Transaction Date    Transaction Time  Risk Assessment  \
# 0          card 1       2023-05-11 1900-01-01 16:22:14            362.0
# 1          card 2       2023-06-05 1900-01-01 15:16:35            602.0
# 2          card 3       2023-06-05 1900-01-01 11:57:40            482.0
# 3          card 4       2023-07-20 1900-01-01 18:26:30            947.0
# 4          card 5       2023-03-03 1900-01-01 19:03:11           1382.0
#
#           Payment Method  Transaction Value Merchant Location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   Card Present Status Chip Usage Cross-border Transaction (Yes/No)  \
# 0                  CP        Yes                                No
# ...

# %%
fraud = df[df['Fraud Indicator (Yes/No)'] == 'Yes']

# %%
fraud_df = df[df['Card Identifier'].isin(fraud['Card Identifier'])]

# %%
# Group by 'Card Identifier' and count the number of transactions
transaction_counts = df.groupby('Card Identifier').size()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(transaction_counts, bins=range(1, 50), edgecolor='black')
plt.xlabel('Number of Transactions')
plt.ylabel('Number of Cards')
plt.title('Histogram of Number of Transactions per Card')
plt.grid(True)
plt.show()

# %%
# Group by 'Card Identifier' and count the number of transactions
transaction_counts = fraud.groupby('Card Identifier').size()

# Plot histogram
plt.figure(figsize=(10, 6))
plt.hist(transaction_counts, bins=range(1, max(transaction_counts) + 2), edgecolor='black')
plt.xlabel('Number of Transactions')
plt.ylabel('Number of Cards')
plt.title('Histogram of Number of Transactions per Card')
plt.grid(True)
plt.show()

# %%
s = df.groupby('Merchant Category Code (MCC)').size().sort_values(ascending=False)
print("Total MCC frequency")
s.head(50)
# Out:
# Total MCC frequency
# Merchant Category Code (MCC)
# 5812.0    16344
# 5814.0    11159
# 5411.0     5611
# 4121.0     4696
# 4829.0     3402
# 5942.0     3043
# 4111.0     2552
# 5499.0     2524
# 5999.0     2339
# 5541.0     1920
# 4899.0     1907
# 5816.0     1904
# 7523.0     1528
# 5813.0     1372
# 5912.0     1315
# 4814.0     1146
# 5818.0     1043
# 7299.0     1018
# 6011.0      874
# 8999.0      848
# 5399.0      837
# 7230.0      819
# 5311.0      811
# 4812.0      789
# 5691.0      784
# 5921.0      780
# 5462.0      756
# 5968.0      751
# 5969.0      677
# 7399.0      603
# 5734.0      596
# 7997.0      585
# 9399.0      570
# 5193.0      552
# 7011.0      551
# 8398.0      546
# 6300.0      542
# 5310.0      533
# 5651.0      533
# 8099.0      505
# 5815.0      463
# 4816.0      448
# 5977.0      438
# 5967.0      432
# 4784.0      425
# 4722.0      422
# 8299.0      418
# 7832.0      405
# 5995.0      394
# 5947.0      353
# dtype: int64

# %%
s = fraud.groupby('Merchant Category Code (MCC)').size().sort_values(ascending=False)
print("Fraud MCC frequency")
s.head(10)
# Out:
# Fraud MCC frequency
# Merchant Category Code (MCC)
# 7311.0    19
# 5812.0    18
# 5814.0    13
# 5816.0    13
# 4899.0    11
# 4829.0    10
# 5942.0     8
# 5734.0     7
# 7372.0     6
# 4121.0     6
# dtype: int64

# %% [markdown]
# - 7311 Advertising Services
# - 5812 Eating Places and Restaurants
# - 5814 Fast Food Restaurants
# - 5411 Grocery Stores, Supermarkets
# - 4121 Taxicabs and Limousines
# - 5816 Digital Goods: Games
# - 4899 Cable, Satellite, and Other Pay Television and Radio
# Service
# - 4829 Wire Transfer Money Orders (V, D, G, X)
# Money Transfer (M)s

# %%
df.shape
# Out:
# (100000, 14)

# %%
df['Card Identifier'].nunique()
# Out:
# 7872

# %%
fraud['Card Identifier'].nunique()
# Out:
# 183

# %%
# fraud['Card Identifier']

# %%
pd.set_option('display.max_rows', 3200)
fraud_df.sort_values(['Card Identifier', 'Transaction Date'], ascending=[True, True])
# Out:
#       Card Identifier Transaction Date    Transaction Time  Risk Assessment  \
# 38899       card 1013       2023-01-02 1900-01-01 21:58:42            807.0
# 46812       card 1013       2023-01-02 1900-01-01 09:33:29            632.0
# 21817       card 1013       2023-01-03 1900-01-01 16:08:46            782.0
# 65579       card 1013       2023-01-03 1900-01-01 18:20:12            672.0
# 20788       card 1013       2023-01-04 1900-01-01 21:40:22            512.0
# 40756       card 1013       2023-01-05 1900-01-01 00:13:27            742.0
# 6478        card 1013       2023-01-09 1900-01-01 01:12:17           1172.0
# 62931       card 1013       2023-01-11 1900-01-01 16:42:17            852.0
# 86316       card 1013       2023-01-13 1900-01-01 09:42:46           1317.0
# 90181       card 1013       2023-01-14 1900-01-01 01:39:14            317.0
# 55660       card 1013       2023-01-19 1900-01-01 16:32:59            512.0
# ...

# %%
# fraud.sort_values(['Card Identifier', 'Transaction Date'], ascending=[True, True])
