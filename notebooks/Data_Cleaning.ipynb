# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 13:04:.0

# %%
data_path = "../data/BOLT Data Set.xlsx"
og_df = pd.read_excel(data_path)
og_df.head()
# Out:
#   Card Identifier Transaction Date Transaction Time  Risk Assessment  \
# 0          card 1       2023-05-11       16:22:14.0            362.0
# 1          card 2       2023-06-05       15:16:35.0            602.0
# 2          card 3       2023-06-05       11:57:40.0            482.0
# 3          card 4       2023-07-20       18:26:30.0            947.0
# 4          card 5       2023-03-03       19:03:11.0           1382.0
#
#           Payment Method  Transaction Value Merchant Location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   Card Present Status Chip Usage Cross-border Transaction (Yes/No)  \
# 0                  CP        Yes                                No
# ...

# %%
clean_df = og_df.copy()

# %%
fraud_yes = clean_df[clean_df["fraud_indicator"] == "Yes"]

# %%
clean_df['Transaction Time'] = pd.to_datetime(clean_df['Transaction Time'], format='%H:%M:%S.%f', errors='coerce').dt.time

# %%
clean_df['transaction_time'].isna().sum()
# Out:
# 22462

# %%
fraud_yes['transaction_time'].isna().sum()
# Out:
# 80

# %%
clean_df.head()
# Out:
#   Card Identifier Transaction Date Transaction Time  Risk Assessment  \
# 0          card 1       2023-05-11         16:22:14            362.0
# 1          card 2       2023-06-05         15:16:35            602.0
# 2          card 3       2023-06-05         11:57:40            482.0
# 3          card 4       2023-07-20         18:26:30            947.0
# 4          card 5       2023-03-03         19:03:11           1382.0
#
#           Payment Method  Transaction Value Merchant Location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   Card Present Status Chip Usage Cross-border Transaction (Yes/No)  \
# 0                  CP        Yes                                No
# ...

# %%
list(og_df.columns)
# Out:
# ['Card Identifier',
#  'Transaction Date',
#  'Transaction Time',
#  'Risk Assessment',
#  'Payment Method',
#  'Transaction Value',
#  'Merchant Location',
#  'Card Present Status',
#  'Chip Usage',
#  'Cross-border Transaction (Yes/No)',
#  'Acquiring Institution ID',
#  'Merchant Identifier',
#  'Merchant Category Code (MCC)',
#  'Fraud Indicator (Yes/No)']

# %%
new_column_names = ['card_id',
 'transaction_date',
 'transaction_time',
 'risk_assessment',
 'payment_method',
 'transaction_value',
 'merchant_location',
 'card_present_status',
 'chip_usage',
 'cross_border_transaction',
 'acquirer_id',
 'merchant_id',
 'merchant_category_code',
 'fraud_indicator']

# %%
clean_df.columns = new_column_names

# %%
clean_df.head()
# Out:
#   card_id transaction_date transaction_time  risk_assessment  \
# 0  card 1       2023-05-11         16:22:14            362.0
# 1  card 2       2023-06-05         15:16:35            602.0
# 2  card 3       2023-06-05         11:57:40            482.0
# 3  card 4       2023-07-20         18:26:30            947.0
# 4  card 5       2023-03-03         19:03:11           1382.0
#
#           payment_method  transaction_value merchant_location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   card_present_status chip_usage cross_border_transaction acquirer_id  \
# 0                  CP        Yes                       No  acquirer 1
# 1                 CNP         No                       No  acquirer 2
# ...

# %%
clean_df.to_csv("../data/data_time_cleaned.csv", index=False)

# %%
clean_df.to_excel('../data/data_time_cleaned.xlsx', index=False)

# %%
df.head()
# Out:
#    Card Identifier Transaction Date    Transaction Time  Risk Assessment  \
# 0                1       2023-05-11 1900-01-01 16:22:14            362.0
# 1                2       2023-06-05 1900-01-01 15:16:35            602.0
# 2                3       2023-06-05 1900-01-01 11:57:40            482.0
# 3                4       2023-07-20 1900-01-01 18:26:30            947.0
# 4                5       2023-03-03 1900-01-01 19:03:11           1382.0
#
#           Payment Method  Transaction Value Merchant Location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   Card Present Status Chip Usage Cross-border Transaction (Yes/No)  \
# 0                  CP        Yes                                No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Card Identifier                    100000 non-null  object
#  1   Transaction Date                   100000 non-null  datetime64[ns]
#  2   Transaction Time                   100000 non-null  object
#  3   Risk Assessment                    99028 non-null   float64
#  4   Payment Method                     100000 non-null  object
#  5   Transaction Value                  100000 non-null  float64
#  6   Merchant Location                  100000 non-null  object
#  7   Card Present Status                100000 non-null  object
#  8   Chip Usage                         100000 non-null  object
#  9   Cross-border Transaction (Yes/No)  100000 non-null  object
#  10  Acquiring Institution ID           100000 non-null  object
# ...

# %%
df['Card Identifier']
# Out:
# 0           card 1
# 1           card 2
# 2           card 3
# 3           card 4
# 4           card 5
#            ...
# 99995    card 1213
# 99996    card 3761
# 99997     card 442
# 99998    card 1769
# 99999    card 6113
# Name: Card Identifier, Length: 100000, dtype: object

# %%
df['Card Identifier'].value_counts()
# Out:
# Card Identifier
# card 300     407
# card 93      282
# card 180     273
# card 276     272
# card 52      266
#             ...
# card 5819      1
# card 5820      1
# card 5823      1
# card 3783      1
# card 7872      1
# Name: count, Length: 7872, dtype: int64

# %%
df['Cross-border Transaction (Yes/No)'].value_counts()
# Out:
# Cross-border Transaction (Yes/No)
# No     85037
# Yes    14845
# 0        118
# Name: count, dtype: int64

# %%
df['Card Identifier'] = df['Card Identifier'].str.replace('card ', '').astype(int)

# %%
df.head()
# Out:
#    Card Identifier Transaction Date    Transaction Time  Risk Assessment  \
# 0                1       2023-05-11 1900-01-01 16:22:14            362.0
# 1                2       2023-06-05 1900-01-01 15:16:35            602.0
# 2                3       2023-06-05 1900-01-01 11:57:40            482.0
# 3                4       2023-07-20 1900-01-01 18:26:30            947.0
# 4                5       2023-03-03 1900-01-01 19:03:11           1382.0
#
#           Payment Method  Transaction Value Merchant Location  \
# 0  Paypass - Contactless              13.98               USA
# 1                 Online              24.64               USA
# 2                Unknown              15.00               USA
# 3                 Online              30.56               USA
# 4        Magnetic Stripe              50.85               USA
#
#   Card Present Status Chip Usage Cross-border Transaction (Yes/No)  \
# 0                  CP        Yes                                No
# ...

# %%
df['card_id'].value_counts()
# Out:
# card_id
# 300     407
# 93      282
# 180     273
# 276     272
# 52      266
#        ...
# 5819      1
# 5820      1
# 5823      1
# 3783      1
# 7872      1
# Name: count, Length: 7872, dtype: int64

# %%
df['Transaction Time'] = pd.to_datetime(df['Transaction Time'], format='%H:%M:%S.%f', errors='coerce')

# %%
# Count the number of values that couldn't be converted
count_invalid = df['transaction_time'].isna().sum()

print("Number of values in unexpected format:", count_invalid)
# Out:
# Number of values in unexpected format: 22462

# %%
df_fraud = df[df['Fraud Indicator (Yes/No)'] == 'Yes']
df_fraud['transaction_time'].isna().sum()
# Out:
# 80

# %%
df['Merchant Location'].value_counts()
# Out:
# Merchant Location
# USA    85155
# GBR     3573
# FRA     1425
# ESP     1018
# NLD      775
#        ...
# BHR        1
# GLP        1
# GUY        1
# BIH        1
# BLR        1
# Name: count, Length: 137, dtype: int64

# %%
df['Risk Assessment'].value_counts()
# Out:
# Risk Assessment
# 277.0     693
# 262.0     685
# 267.0     681
# 302.0     678
# 257.0     676
#          ...
# 4222.0      1
# 4477.0      1
# 4917.0      1
# 4847.0      1
# 4867.0      1
# Name: count, Length: 951, dtype: int64

# %%
df.columns
# Out:
# Index(['Card Identifier', 'Transaction Date', 'Transaction Time',
#        'Risk Assessment', 'Payment Method', 'Transaction Value',
#        'Merchant Location', 'Card Present Status', 'Chip Usage',
#        'Cross-border Transaction (Yes/No)', 'Acquiring Institution ID',
#        'Merchant Identifier', 'Merchant Category Code (MCC)',
#        'Fraud Indicator (Yes/No)', 'card_id', 'transaction_time'],
#       dtype='object')
